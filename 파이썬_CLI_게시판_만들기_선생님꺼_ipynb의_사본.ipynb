# %% [markdown]
# <a href="https://colab.research.google.com/github/jungjeeo0428/using-_python_make_aboard/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_CLI_%EA%B2%8C%EC%8B%9C%ED%8C%90_%EB%A7%8C%EB%93%A4%EA%B8%B0_%EC%84%A0%EC%83%9D%EB%8B%98%EA%BA%BC_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("== CLI 게시판 실행 ==")

while True:
    cmd = input("명령어 ) ")

    if cmd == "exit":
      break

    elif cmd == "article write":
      input("제목 : ")
      input("내용 : ")
      print("1번 글이 생성되었습니다")
    else:
      print("지원하지 않는 기능입니다")

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) ㅁㅇㄹㅎadfadfg
# 지원하지 않는 기능입니다
# 명령어 ) asdfggdfas
# 지원하지 않는 기능입니다
# 명령어 ) xcvbnxcvb
# 지원하지 않는 기능입니다
# 명령어 ) article write
# 제목 : sdfgh
# 내용 :
# 1번 글이 생성되었습니다
# 명령어 ) exit
# == CLI 게시판 종료 ==
